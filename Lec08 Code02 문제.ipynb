# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## 1-1.weight-height.csv 데이터 불러오기 (5점)

# %%
df = 
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %% [markdown]
# ## 1-2.x=height, y=weight로 설정해 plot하기 (5점)

# %% [markdown]
# ## 1-3. 선형 회귀 모델 생성하고 데이터 fit시키기 (10점)

# %%
# Out:
# LinearRegression()

# %% [markdown]
# ## 1-4. 키가 70인 사람 예측해보기 (10점)

# %%
# Out:
# array([189.47294304])

# %% [markdown]
# ## 1-5. 기울기, 절편 구하기 (10점)

# %%
# Out:
# (array([7.71728764]), -350.737191812137)

# %% [markdown]
# ## 1-6. 기존 x 값으로 y를 예측해 그래프 그리기 (10점)

# %% [markdown]
# ## 2-1. 데이터 불러오기 (5점)
# 'brain_size.csv',sep = ';',index_col=0 으로 데이터를 불러오세요

# %%
data_df = 
data_df.head()
# Out:
#    Gender  FSIQ  VIQ  PIQ Weight Height  MRI_Count
# 1  Female   133  132  124    118   64.5     816932
# 2    Male   140  150  124      .   72.5    1001121
# 3    Male   139  123  150    143   73.3    1038437
# 4    Male   133  129  128    172   68.8     965353
# 5  Female   137  132  134    147   65.0     951545

# %% [markdown]
# ## 2-2. 데이터 정보 불러오기 (5점)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 1 to 40
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Gender     40 non-null     object
#  1   FSIQ       40 non-null     int64
#  2   VIQ        40 non-null     int64
#  3   PIQ        40 non-null     int64
#  4   Weight     40 non-null     object
#  5   Height     40 non-null     object
#  6   MRI_Count  40 non-null     int64
# dtypes: int64(4), object(3)
# memory usage: 2.5+ KB

# %% [markdown]
# ## 2-3. Height와 Weight의 결손데이터를 삭제하고 데이터 타입을 float으로 만들기 ( 결손 데이터는 '.' 으로 표현 되어 있습니다) (5점)

# %%
# Out:
# Gender       0
# FSIQ         0
# VIQ          0
# PIQ          0
# Weight       2
# Height       1
# MRI_Count    0
# dtype: int64
# Gender       0
# FSIQ         0
# VIQ          0
# PIQ          0
# Weight       0
# Height       0
# MRI_Count    0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 1 to 40
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Gender     38 non-null     object
#  1   FSIQ       38 non-null     int64
#  2   VIQ        38 non-null     int64
#  3   PIQ        38 non-null     int64
#  4   Weight     38 non-null     float64
#  5   Height     38 non-null     float64
#  6   MRI_Count  38 non-null     int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 2.4+ KB

# %% [markdown]
# ## 2-4. statsmodel.api.OLS 또는 statsmodel.formula.api.ols를 사용하여 선형회귀 모델 만들기 (5점)
# Weight, Height, MRI_Count를 원인 변수로 넣어 regress out 한뒤 summary표 확인하세요

# %%
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    VIQ   R-squared:                       0.249
# Model:                            OLS   Adj. R-squared:                  0.158
# Method:                 Least Squares   F-statistic:                     2.733
# Date:                Wed, 04 May 2022   Prob (F-statistic):             0.0455
# Time:                        07:48:45   Log-Likelihood:                -167.03
# No. Observations:                  38   AIC:                             344.1
# Df Residuals:                      33   BIC:                             352.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        169.7719     90.054      1.885      0.068     -13.443     352.987
# ...

# %% [markdown]
# ## 2-5. 위에서 만든 OLS 모델로 PLOT하기 (10점)
# statsmodel.api.graphics.plot_regress_exog를 이용해 regression plots for weight를 출력하세요

# %% [markdown]
# ## 2-6. get_dummies 메서드로 범주형 데이터를 양적 데이터로 전환하기 (10점)

# %%
# Out:
#       Female  Male
# 0          0     1
# 1          0     1
# 2          0     1
# 3          0     1
# 4          0     1
# ...      ...   ...
# 9995       1     0
# 9996       1     0
# 9997       1     0
# 9998       1     0
# 9999       1     0
#
# [10000 rows x 2 columns]

# %% [markdown]
# ## 2-7. statsmodel.api.OLS를 이용한 회귀 모델 만들기 (10점)
# 종속변수는 weight, 독립변수는 female,male로 설정하고
# 2-6을 이용해 회귀 모델을 만드세요

# %%
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.635
# Model:                            OLS   Adj. R-squared:                  0.635
# Method:                 Least Squares   F-statistic:                     8683.
# Date:                Wed, 04 May 2022   Prob (F-statistic):               0.00
# Time:                        07:48:48   Log-Likelihood:                -43845.
# No. Observations:               10000   AIC:                         8.770e+04
# Df Residuals:                    9997   BIC:                         8.772e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Female      2.389e+13   1.37e+13      1.740      0.082   -3.02e+12    5.08e+13
# ...
