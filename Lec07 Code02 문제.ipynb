# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

# %% [markdown]
# # 1. t-test(20점)

# %% [markdown]
# ### 1-1. 데이터 불러오기
# weight-height.csv 데이터를 불러와 People로 정의하기

# %%
People = 
People.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %% [markdown]
# ### 1-2. KDE plot
# People의 Height 값을 Sample_A로 정의하고 그 값을 KDE Plot 하기

# %% [markdown]
# 여성 집단의 몸무게 데이터를 Sample_F, <br>
# 남성 집단의 몸무게 데이터를 Sample_M 이라고 정의하고 kde plot하기

# %%
# two sample t-test

# %% [markdown]
# ### 1-3. The null hypothesis
#
# height 데이터 가설 검정하기<br>
# <BR>
# 1. 65kg로 Sample_A의 height 데이터 값 을 t-test검정했을때 p-value 값이 0.05 보다 작으면 'mean value of Sample A differs' 와 해당값의 p-value 값을 같이 출력하기

# %%
from scipy import stats

# Perform t-test and print result

# Test significance
# Out:
# mean value of Sample A differs from given value
# p-value: 1.089548024807223e-260

# %% [markdown]
# 2. Sample_M과 Sample_F를 두 데이터를 t-test 검증하고
# p-value가 0.05보다 작을때 p-value값과'mean value of Sample_M differs from Sample_M' 함께 출력하기

# %%
# Out:
# mean value of Sample M differs from Sample F
# p-value: 0.0

# %% [markdown]
# # 2. chi - squared test(20점)

# %% [markdown]
# ### 2- 1. 범주형 데이터 불러오기
# bank-full.csv 가져오기

# %%
# Categorical Dataset
df = 
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome Target
# 0  unknown    5   may       261         1     -1         0  unknown     no
# 1  unknown    5   may       151         1     -1         0  unknown     no
# 2  unknown    5   may        76         1     -1         0  unknown     no
# 3  unknown    5   may        92         1     -1         0  unknown     no
# 4  unknown    5   may       198         1     -1         0  unknown     no

# %% [markdown]
# ### 2- 2. crosstab
#
# index 는 job , columns는 education으로 설정하고 pandas.crosstab()을 이용해 contigency table 만들기

# %%
#contingency table
# Out:
# education      primary  secondary  tertiary  unknown
# job
# admin.             209       4219       572      171
# blue-collar       3758       5371       149      454
# entrepreneur       183        542       686       76
# housemaid          627        395       173       45
# management         294       1121      7801      242
# retired            795        984       366      119
# self-employed      130        577       833       39
# services           345       3457       202      150
# student             44        508       223      163
# technician         158       5229      1968      242
# unemployed         257        728       289       29
# unknown             51         71        39      127

# %% [markdown]
# ### 2-3 chi squared test 실시
# 위에서 만든 table로 카이제곱 검증 하고 자유도 출력하기

# %%
# chi-squared test with similar proportions
# Out:
# education      primary  secondary  tertiary  unknown
# job
# admin.             209       4219       572      171
# blue-collar       3758       5371       149      454
# entrepreneur       183        542       686       76
# housemaid          627        395       173       45
# management         294       1121      7801      242
# retired            795        984       366      119
# self-employed      130        577       833       39
# services           345       3457       202      150
# student             44        508       223      163
# technician         158       5229      1968      242
# unemployed         257        728       289       29
# unknown             51         71        39      127
#
# dof = 33

# %% [markdown]
# ### 2-4 임계값 구하기

# %% [markdown]
# 1. level of confidence=0.95로 설정한 후 신뢰구간,임계값,t-statistic을 출력하기 (chi2.ppf이용)
# 2. t-statistic 값이 임계값보다 크거나 같으면 Dependent(reject H0)를, 그렇지 않으면 Independent (fail to reject HO)을 출력하기

# %%
# interpret test-statistic
# Out:
# Probability = 0.95, Critical Value = 47.4, Test Statistic = 28483.136
#
# Dependent (reject H0)

# %% [markdown]
# ### 2-5 p-value

# %% [markdown]
# 1. alpha=0.05로 설정한 후 alpha,p-value값 출력하기
# 2. p-value값이 alpha보다 작거나 같으면 Dependent(reject H0)를, 그렇지 않으면 Independent (fail to reject HO)을 출력하기

# %%
# interpret p-value
# Out:
# Significance Level = 0.05, P-Value = 0.0
#
# Dependent (reject H0)

# %% [markdown]
# # 3. Fisher's exact test(20점)

# %% [markdown]
# ### 3-1.데이터불러오기
# 'https://assets.datacamp.com/production/repositories/4371/datasets/8fd0a14bfbc5f13719d92334eaf77b23f2e914d6/olyathswim.csv'
# 에서 데이터불러오기

# %%
athletes = 
athletes.head()
# Out:
#    Unnamed: 0                                Name Sex   Age  Height  Weight  \
# 0          27  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 1          28  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 2          30      Einar Ferdinand "Einari" Aalto   M  26.0     NaN     NaN
# 3          36                Arvo Ossian Aaltonen   M  22.0     NaN     NaN
# 4          37                Arvo Ossian Aaltonen   M  22.0     NaN     NaN
#
#           Team  NOC        Games  Year         City      Sport  \
# 0  Netherlands  NED  1932 Summer  1932  Los Angeles  Athletics
# 1  Netherlands  NED  1932 Summer  1932  Los Angeles  Athletics
# 2      Finland  FIN  1952 Summer  1952     Helsinki   Swimming
# 3      Finland  FIN  1912 Summer  1912    Stockholm   Swimming
# 4      Finland  FIN  1912 Summer  1912    Stockholm   Swimming
#
#                                     Event Medal
# 0            Athletics Women's 100 metres   NaN
# ...

# %% [markdown]
# ### 3-2 데이터 종류 나열하기

# %% [markdown]
# 'Medal' 데이터의 종류 알아보기

# %%
# Out:
# array([nan, 'Bronze', 'Silver', 'Gold'], dtype=object)

# %% [markdown]
# ### 3-3 데이터 처리하기

# %% [markdown]
# 1. 'Bronze': True, 'Silver': True, 'Gold': True 인 값을 갖는 데이터를 'MedalTF'라는 새로운 데이터에 저장하고 결측값은 False로 채우기<br>
# 2. 'Medal'데이터의 결측치는 None으로 채우기
# 3. atheletes의 결측값있는 행 제거하기

# %% [markdown]
# ### 3-4 fisher exact test하기
#
# 1. MedalTF와 Sport 데이터로 crosstab한 table 생성하기
# 2. alpha=0.05로 설정해 fisher exact test한 p-value값과 비교했을때 p-value 값이 alpha 보다 작으면 'Proportions of medal winners differ significantly' + p-value 를 , 그렇지 않다면 'No significant difference in proportions of medal winners found'+p-value 를 출력하기

# %%
# Out:
# Sport    Athletics  Swimming
# MedalTF
# False        28726     16290
# True          3648      2486
#
# Proportions of medal winners differ significantly
# p-value: 5.091646967990442e-11

# %% [markdown]
# # 4. One - way ANOVA(20점)

# %% [markdown]
# ### 4-1. boxplot
# x= 'Team'의 France, United States , China  <br>
# y= 'Weight'로 설정하고 boxplot하기

# %% [markdown]
# ### 4-2. one - way ANOVA 분석하기
# France , United States, China 의 weight을 one way anova 방식으로 분석하고 statistic 값과 p-value 값을 출력하기

# %%
# Out:
# Test Statistic = 55.63, P-value = 0.0

# %% [markdown]
# # 5. Two - way ANOVA(20점)

# %% [markdown]
# ### 5-1. boxplot
#
# x= Team 의 United States, China <br>
# y= Weight 로 설정하고
# 성별에 따라 boxplot 하기

# %% [markdown]
# ### 5-2 . two-way anova 분석하기

# %% [markdown]
# 몸무게 데이터를 성별과 팀에 따라 two way anova 분석하기

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#                 sum_sq       df             F  PR(>F)
# Sex       2.639780e+06      1.0  20144.562135     0.0
# Team      9.344392e+05    228.0     31.275651     0.0
# Residual  6.672648e+06  50920.0           NaN     NaN
