# %% [markdown]
# ## 데이터 불러오기

# %%
import pandas as pd
df = pd.read_csv('iris.csv')
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ##  1) 품종별로 그룹화 한 후 히스토그램 그리기

# %%
# 그룹화

# 히스토그램 그리기
# Out:
# variety
# Setosa        [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# Versicolor    [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# Virginica     [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# dtype: object

# %% [markdown]
# ## 2) 품종별로 그룹화하여 평균 , 중간값, 표준편차, 백분위 구하기

# %%
print('------------------------------mean-------------------------------')
print()
print('-----------------------------median------------------------------')
print()
print('------------------------------std-------------------------------')
print()
print('----------------------------quantile-----------------------------')
print()
# Out:
# ------------------------------mean-------------------------------
#             sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa             5.006        3.428         1.462        0.246
# Versicolor         5.936        2.770         4.260        1.326
# Virginica          6.588        2.974         5.552        2.026
# -----------------------------median------------------------------
#             sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa               5.0          3.4          1.50          0.2
# Versicolor           5.9          2.8          4.35          1.3
# Virginica            6.5          3.0          5.55          2.0
# ------------------------------std-------------------------------
#             sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa          0.352490     0.379064      0.173664     0.105386
# Versicolor      0.516171     0.313798      0.469911     0.197753
# ...

# %% [markdown]
# ## 3) sepal length, sepal width, petal length, petal width 별로 mean, trim mean, weighted mean, median 값 확인하기

# %%
from scipy import stats
import numpy as np

print("sepal.width")
print("mean:",)
print("trim mean:",)
print("weighted mean:",)
print("median:",)
print("\n")

print("sepal.length")
print("mean:",)
print("trim mean:",)
print("weighted mean:",)
print("median:",)
print("\n")

print("petal.width")
print("mean:",)
print("trim mean:",)
print("weighted mean:",)
print("median:",)
print("\n")

print("petal.length")
print("mean:",)
print("trim mean:",)
print("weighted mean:",)
print("median:",)
# Out:
# sepal.width
# mean: 3.057333333333334
# trim mean: 3.0433333333333334
# weighted mean: 2.955758389261745
# median: 3.0
#
#
# sepal.length
# mean: 5.843333333333335
# trim mean: 5.8083333333333345
# weighted mean: 6.18710514541387
# median: 5.8
#
#
# petal.width
# mean: 1.199333333333334
# trim mean: 1.1841666666666668
# weighted mean: 1.5967337807606263
# median: 1.3
#
#
# petal.length
# mean: 3.7580000000000027
# trim mean: 3.7600000000000002
# weighted mean: 4.660572706935122
# median: 4.35

# %% [markdown]
# ## 4-1) sepal length, sepal width, petal length, petal width 별로 value counts 구하기

# %%
print("sepal length")
print()

print('sepal width')
print()

print('petal length')
print()

print('petal width')
print()
# Out:
# sepal length
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: sepal.length, dtype: int64
# sepal width
# 3.0    26
# 2.8    14
# 3.2    13
# 3.4    12
# 3.1    11
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.6     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: sepal.width, dtype: int64
# petal length
# 1.4    13
# 1.5    13
# 5.1     8
# 4.5     8
# 1.6     7
# 1.3     7
# 5.6     6
# 4.7     5
# 4.9     5
# 4.0     5
# 4.2     4
# 5.0     4
# 4.4     4
# 4.8     4
# 1.7     4
# ...

# %% [markdown]
# ## 4-2) sepal length, sepal width, petal length, petal width 별로 value counts 막대 그래프로 그리기

# %%
import matplotlib.pyplot as plt

f, axes = plt.subplots(4,1)
f.set_size_inches((10, 40))
plt.subplots_adjust(wspace = 0.3, hspace = 0.3)

ax1=
ax1.set_title('sepal width')
ax1.set_xlabel('sepal width')
ax1.set_ylabel('value counts')

ax2=
ax2.set_title('sepal length')
ax2.set_xlabel('sepal length')
ax2.set_ylabel('value counts')

ax3=
ax3.set_title('petal width')
ax3.set_xlabel('petal width')
ax3.set_ylabel('value counts')

ax4=
ax4.set_title('petal length')
ax4.set_xlabel('petal length')
ax4.set_ylabel('value counts')
# Out:
# Text(0, 0.5, 'value counts')

# %% [markdown]
# ## 5) sepal length, sepal width, petal length, petal width 별 IQR (Inter Quartile Range) 계산하기

# %%
percentile75_sl=
percentile25_sl=
IQR_sl = percentile75_sl - percentile25_sl
print('IQR of sepal length:',IQR_sl)

percentile75_sw=
percentile25_sw=
IQR_sw = percentile75_sw - percentile25_sw
print('IQR of sepal width:',IQR_sw)

percentile75_pl=
percentile25_pl=
IQR_pl = percentile75_pl - percentile25_pl
print('IQR of petal length:',IQR_pl)

percentile75_pw=
percentile25_pw=
IQR_pw = percentile75_pw - percentile25_pw
print('IQR of petal width:',IQR_pw)
# Out:
# IQR of sepal length: 1.3000000000000007
# IQR of sepal width: 0.5
# IQR of petal length: 3.4999999999999996
# IQR of petal width: -3.3

# %% [markdown]
# ## 6-1) 상관관계 계산하기

# %%
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# ## 6-2) 상관관계 Heatmap으로 그리기 ( seaborn 활용 )

# %%
import seaborn as sns

# %% [markdown]
# ## 7) Pivot Table 활용한 Plot으로서, index가 품종인 피벗 테이블을 생성하고 ggplot 스타일을 이용해 테이블을 plot하기

# %%
# Out:
#             petal.length  petal.width  sepal.length  sepal.width
# variety
# Setosa             1.462        0.246         5.006        3.428
# Versicolor         4.260        1.326         5.936        2.770
# Virginica          5.552        2.026         6.588        2.974

# %% [markdown]
# ## 8) Boxplot 그리기

# %% [markdown]
# ## 9-1) Kdeplot 그리기 : x축은 sepal length, y축은 sepal width로 설정하고 kdeplot하기

# %% [markdown]
# ## 9-2) Kdeplot 그리기 : x축은 petal length, y축은 petal width로 설정하고 kdeplot하기
